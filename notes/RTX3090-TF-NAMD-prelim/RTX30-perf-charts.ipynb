# %%
import pandas as pd  # data handeling
import numpy as np   # numeriacal computing
import matplotlib.pyplot as plt  # plotting core
import seaborn as sns  # higher level plotting tools
# %matplotlib inline
sns.set()

# %%
df = pd.DataFrame({'GPU':[
    '4 x 2080Ti+2NVLINK'   ,
    '4 x 2080Ti'           ,
    '4 x 2080+2NVLINK'     ,
    '4 x 2080'             ,
    '4 x 1080Ti'           ,
    '4 x 2070'             ,
    '2 x RTX Titan+2NVLINK',
    '2 x RTX Titan'        ,
    '2 x Titan V'          ,
    '2 x 2080Ti+NVLINK'    ,
    '2 x 2080Ti'           ,
    '4 x 1070'             ,
    '** 1 x RTX3080'       ,
    '2 x 2080+NVLINK'      ,
    '2 x 2070Super+NVLINK' , 
    '2 x 2080'             ,
    '2 x 1080Ti'           ,
    '2 x 2070Super'        ,
    '** 1 x RTX Titan'     ,
    '2 x 2070'             ,
    '1 x RTX Titan'        ,
    '1 x 2080Ti'           ,
    '1 x Titan V'          ,
    '2 x 1070'             ,
    '1 x 2080'             ,
    '2 x 1660Ti'           ,
    '1 x 2070Super'        , 
    '1 x 1080Ti'           ,
    '1 x 2070'             ,
    '1 x 1070'             ,
    '1 x 1660Ti'           ],
    'images/second':[
    1009,
    989,
    778,
    763,
    760,
    680,
    629,
    628,
    528,
    527,
    506,
    471,
    462,    
    399,
      389,
    389,
    387,
      384,
    373,
    351,
    332,
    293,
    288,
    241,
    218,
    216,
      210,  
    211,
    191,
    126,
    119
]})

# %%
df
# Out:
#                       GPU  images/second
# 0      4 x 2080Ti+2NVLINK           1009
# 1              4 x 2080Ti            989
# 2        4 x 2080+2NVLINK            778
# 3                4 x 2080            763
# 4              4 x 1080Ti            760
# 5                4 x 2070            680
# 6   2 x RTX Titan+2NVLINK            629
# 7           2 x RTX Titan            628
# 8             2 x Titan V            528
# 9       2 x 2080Ti+NVLINK            527
# 10             2 x 2080Ti            506
# 11               4 x 1070            471
# 12         ** 1 x RTX3080            462
# 13        2 x 2080+NVLINK            399
# 14   2 x 2070Super+NVLINK            389
# 15               2 x 2080            389
# 16             2 x 1080Ti            387
# 17          2 x 2070Super            384
# 18       ** 1 x RTX Titan            373
# 19               2 x 2070            351
# 20          1 x RTX Titan            332
# 21             1 x 2080Ti            293
# ...

# %%
plt.figure(figsize=(9,17))

clrs = sns.color_palette("Greens_d", 31)
#print(clrs)
for i in [12,18]: clrs[i]=sns.xkcd_rgb["gold"]

ax = sns.barplot(y="GPU", x="images/second", data=df, palette=clrs)
ax.set_xlim(0,1200)
ax.set_title("ResNet-50 CNN Train - FP32", fontsize=18)

y = df['images/second']
for i, v in enumerate(y):
    ax.text(v , i + .125, str(v), color='black', fontweight='normal')

# %%
df = pd.DataFrame({'GPU':[
    '4 x 2080Ti+2NVLINK'   ,
    '4 x 2080Ti'           ,
    '4 x 2080+2NVLINK'     ,
    '4 x 2080'             ,
    '2 x RTX Titan+2NVLINK',
    '2 x RTX Titan'        ,
    '4 x 2070'             ,
    '2 x Titan V'          ,
    '** 1 x RTX Titan'     ,
    '** 1 x RTX3080'       ,
    '2 x 2080Ti+NVLINK'    ,
    '2 x 2080Ti'           ,
    '2 x 2080+NVLINK'      ,
    '2 x 2080'             ,
    '2 x 2070Super+NVLINK' , 
    '2 x 2070Super'        , 
    '1 x RTX Titan'        ,
    '1 x Titan V'          ,
    '2 x 2070'             ,
    '1 x 2080Ti'           ,
    '1 x 2080'             ,
    '1 x 2070Super'        , 
    '1 x 2070'             ,
    '2 x 1660Ti'           ,
    '1 x 1660Ti'           ],
    'images/second':[
    1821,
    1780,
    1302,
    1245,
    1242,
    1241,
    1142,
    1111,
    1082,
    1023,
    953,
    909,
    665,
    662,
      654,
      654,
    653,
    624,
    607,
    532,
    382,
      368,
    338,
    288,
    152
]})

# %%
df
# Out:
#                       GPU  images/second
# 0      4 x 2080Ti+2NVLINK           1821
# 1              4 x 2080Ti           1780
# 2        4 x 2080+2NVLINK           1302
# 3                4 x 2080           1245
# 4   2 x RTX Titan+2NVLINK           1242
# 5           2 x RTX Titan           1241
# 6                4 x 2070           1142
# 7             2 x Titan V           1111
# 8        ** 1 x RTX Titan           1082
# 9          ** 1 x RTX3080           1023
# 10      2 x 2080Ti+NVLINK            953
# 11             2 x 2080Ti            909
# 12        2 x 2080+NVLINK            665
# 13               2 x 2080            662
# 14   2 x 2070Super+NVLINK            654
# 15          2 x 2070Super            654
# 16          1 x RTX Titan            653
# 17            1 x Titan V            624
# 18               2 x 2070            607
# 19             1 x 2080Ti            532
# 20               1 x 2080            382
# 21          1 x 2070Super            368
# ...

# %%
plt.figure(figsize=(9,12))

clrs = sns.color_palette("Greens_d", 25)
#print(clrs)
for i in [8,9]: clrs[i]=sns.xkcd_rgb["gold"]

#sns.set_context("talk", font_scale=.9)
ax = sns.barplot(y="GPU", x="images/second", data=df, palette=clrs)
ax.set_xlim(0,2000)
ax.set_title("ResNet-50 CNN Train - FP16 (Tensorcores)", fontsize=18)

y = df['images/second']
for i, v in enumerate(y):
    ax.text(v , i + .125, str(v), color='black', fontweight='normal')

# %%
df = pd.DataFrame({'GPU':[
    '4 x 2080Ti+2NVLINK'   ,
    '4 x 2080Ti'           ,
    '4 x 1080Ti'           ,
    '2 x RTX Titan+2NVLINK',
    '2 x 2080Ti+NVLINK'    ,
    '2 x RTX Titan'        ,
    '2 x 2080Ti'           ,
    '4 x 2080+2NVLINK'     ,
    '2 x Titan V'          ,
    '4 x 2080'             ,
    '2 x 1080Ti'           ,
    '4 x 2070'             ,
    '4 x 1070'             ,
    '2 x 2080+NVLINK'      ,
    '2 x 2070Super+NVLINK' , 
    '1 x RTX Titan'        ,
    '1 x 2080Ti'           ,
    '2 x 2080'             ,
    '2 x 2070Super'        , 
    '2 x 2070'             ,
    '1 x Titan V'          ,
    '2 x 1070'             ,
    '1 x 1080Ti'           ,
    '1 x 2080'             ,
    '1 x 2070Super'        , 
    '1 x 2070'             ,
    '2 x 1660Ti'           ,
    '1 x 1070'             ,
    '1 x 1660Ti'           ],
    'words/second':[
    24074,
    20998,
    20360,
    18354,
    16784,
    16483,
    14331,
    14299,
    12903,
    12333,
    11786,
    11696,
    11021,
    9911,
      9695,
    9410,
    8732,
    8530,
      8258,
    7886,
    7373,
    6460,
    6138,
    5059,
      4867,
    4645,
    4191,
    3435,
    2483
]})

# %%
df
# Out:
#                       GPU  words/second
# 0      4 x 2080Ti+2NVLINK         24074
# 1              4 x 2080Ti         20998
# 2              4 x 1080Ti         20360
# 3   2 x RTX Titan+2NVLINK         18354
# 4       2 x 2080Ti+NVLINK         16784
# 5           2 x RTX Titan         16483
# 6              2 x 2080Ti         14331
# 7        4 x 2080+2NVLINK         14299
# 8             2 x Titan V         12903
# 9                4 x 2080         12333
# 10             2 x 1080Ti         11786
# 11               4 x 2070         11696
# 12               4 x 1070         11021
# 13        2 x 2080+NVLINK          9911
# 14   2 x 2070Super+NVLINK          9695
# 15          1 x RTX Titan          9410
# 16             1 x 2080Ti          8732
# 17               2 x 2080          8530
# 18          2 x 2070Super          8258
# 19               2 x 2070          7886
# 20            1 x Titan V          7373
# 21               2 x 1070          6460
# ...

# %%
plt.figure(figsize=(9,15))

clrs = sns.color_palette("Greens_d", 29)
#print(clrs)
for i in [14,18,24]: clrs[i]=sns.xkcd_rgb["red"]

#sns.set_context("talk", font_scale=.9)
ax = sns.barplot(y="GPU", x="words/second", data=df, palette=clrs)
ax.set_xlim(0,28000)
ax.set_title("Billion Word LSTM Train - FP32", fontsize=18)

y = df['words/second']
for i, v in enumerate(y):
    ax.text(v , i + .125, str(v), color='black', fontweight='normal')
