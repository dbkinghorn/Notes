# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import seaborn as sns
sns.set() # not using seaborn but this makes the plots look better
# %matplotlib inline

# %%
w=np.array([
180,
190,
200,
210,
220,
230,
240,
250,
260,
270,
280,
290,
300,
310,
320,
330,
340,
350,])

# %%
fp32x1=np.array([
236.8,
264.0,
305.2,
333.9,
372.0,
402.5,
434.8,
460.2,
479.7,
494.3,
508.6,
519.0,
525.4,
531.1,
535.0,
540.5,
542.5,
544.3,])

# %%
def fcn(x,a,b,c):
    return a  + b*x + c*np.log(1+x)
    #return a + b*np.log2(c*x+d)
popt, pcov = curve_fit(fcn, w, fp32x1)
popt
# Out:
# array([-8.38597282e+03, -5.26458024e+00,  1.83816919e+03])

# %%
plt.rcParams["figure.figsize"] = [12,7]
fig, ax = plt.subplots()
ax.plot( w, fp32x1, "o", color='g')  # plot the test data
xt = np.linspace(160,350,100)
ax.plot(xt, fcn(xt,*popt) )  # plot the model function
#  ,  label='a/((1-b)+(b/n)) with a=%2.6f b=%2.6f n=%2.6f' % tuple(popt)
max95 = fp32x1[-1]*0.95
xp = np.linspace(max95,max95,100)
ax.plot(xt,xp, color='y', label='95% of peak')

plt.xlabel("Watts")
plt.ylabel("images/sec")
plt.title("1 x RTX3090 TensorFlow ResNet50 fp32 -- Watts vs Performance", fontsize=18)
ax.legend()

# %%
fp32x2=np.array([
595.0,
587.3,
589.5,
657.8,
715.1,
772.6,
832.9,
864.0,
885.1,
907.4,
922.5,
929.9,
943.0,
950.0,
956.2,
962.8,
964.2,
969.2,])

# %%
popt, pcov = curve_fit(fcn, w, fp32x2)
popt
# Out:
# array([-1.06524503e+04, -6.68004194e+00,  2.38259275e+03])

# %%
plt.rcParams["figure.figsize"] = [12,7]
fig, ax = plt.subplots()
ax.plot( w, fp32x2, "o", color='g')  # plot the test data
xt = np.linspace(160,350,100)
ax.plot(xt, fcn(xt,*popt) )  # plot the model function
#  ,  label='a/((1-b)+(b/n)) with a=%2.6f b=%2.6f n=%2.6f' % tuple(popt)
max95 = fp32x2[-1]*0.95
xp = np.linspace(max95,max95,100)
ax.plot(xt,xp, color='y', label='95% of peak')

plt.xlabel("Watts")
plt.ylabel("images/sec")
plt.title("2 x RTX3090 TensorFlow ResNet50 fp32 -- Watts vs Performance", fontsize=18)
ax.legend()

# %%
fp32x3=np.array([
 781.8,
 886.5,
 957.0,
 942.1,
1043.4,
1129.1,
1210.9,
1275.9,
1308.2,
1336.0,
1360.3,
1377.9,
1393.7,
1405.0,
1412.5,
1419.0,
1429.3,
1434.3,])

# %%
popt, pcov = curve_fit(fcn, w, fp32x3)
popt
# Out:
# array([-1.70219702e+04, -1.08308548e+01,  3.79598928e+03])

# %%
plt.rcParams["figure.figsize"] = [12,7]
fig, ax = plt.subplots()
ax.plot( w, fp32x3, "o", color='g')  # plot the test data
xt = np.linspace(160,350,100)
ax.plot(xt, fcn(xt,*popt) )  # plot the model function
#  ,  label='a/((1-b)+(b/n)) with a=%2.6f b=%2.6f n=%2.6f' % tuple(popt)
max95 = fp32x3[-1]*0.95
xp = np.linspace(max95,max95,100)
ax.plot(xt,xp, color='y', label='95% of peak')

plt.xlabel("Watts")
plt.ylabel("images/sec")
plt.title("3 x RTX3090 TensorFlow ResNet50 fp32 -- Watts vs Performance", fontsize=18)
ax.legend()

# %%
fp32x4=np.array([
1006.5,
1128.8,
1157.5,
1257.0,
1367.0,
1491.5,
1588.5,
1669.6,
1726.9,
1770.1,
1803.7,
1825.5,
1839.6,
1855.0,
1871.9,
1874.5,
1885.9,
1897.9,])

# %%
popt, pcov = curve_fit(fcn, w, fp32x4)
popt
# Out:
# array([-2.46435182e+04, -1.57911469e+01,  5.47113609e+03])

# %%
plt.rcParams["figure.figsize"] = [12,7]
fig, ax = plt.subplots()
ax.plot( w, fp32x4, "o", color='g')  # plot the test data
xt = np.linspace(160,350,100)
ax.plot(xt, fcn(xt,*popt) )  # plot the model function
#  ,  label='a/((1-b)+(b/n)) with a=%2.6f b=%2.6f n=%2.6f' % tuple(popt)
max95 = fp32x4[-1]*0.95
xp = np.linspace(max95,max95,100)
ax.plot(xt,xp, color='y', label='95% of peak')

plt.xlabel("Watts")
plt.ylabel("images/sec")
plt.title("4 x RTX3090 TensorFlow ResNet50 fp32 -- Watts vs Performance", fontsize=18)
ax.legend()

# %%
fp16x1=np.array([
 648.1,
 784.5,
 817.3,
 986.2,
 976.7,
1048.1,
1104.3,
1148.1,
1235.6,
1213.8,
1233.5,
1247.5,
1260.7,
1278.0,
1276.6,
1293.8,
1306.5,
1308.2,])

# %%
popt, pcov = curve_fit(fcn, w, fp16x1)
popt
# Out:
# array([-1.87513809e+04, -1.25898477e+01,  4.17127696e+03])

# %%
plt.rcParams["figure.figsize"] = [12,7]
fig, ax = plt.subplots()
ax.plot( w, fp16x1, "o", color='g')  # plot the test data
xt = np.linspace(160,350,100)
ax.plot(xt, fcn(xt,*popt) )  # plot the model function
#  ,  label='a/((1-b)+(b/n)) with a=%2.6f b=%2.6f n=%2.6f' % tuple(popt)
max95 = fp16x1[-1]*0.95
xp = np.linspace(max95,max95,100)
ax.plot(xt,xp, color='y', label='95% of peak')

plt.xlabel("Watts")
plt.ylabel("images/sec")
plt.title("1 x RTX3090 TensorFlow ResNet50 fp16 -- Watts vs Performance", fontsize=18)
ax.legend()

# %%
fp16x2=np.array([
1389.4,
1528.8,
1635.6,
1825.1,
1945.8,
2039.5,
2098.2,
2138.2,
2166.9,
2182.7,
2203.9,
2221.3,
2235.7,
2254.9,
2260.7,
2269.9,
2290.7,
2297.5,])

# %%
popt, pcov = curve_fit(fcn, w, fp16x2)
popt
# Out:
# array([-2.97907224e+04, -2.13059520e+01,  6.73848467e+03])

# %%
plt.rcParams["figure.figsize"] = [12,7]
fig, ax = plt.subplots()
ax.plot( w, fp16x2, "o", color='g')  # plot the test data
xt = np.linspace(160,350,100)
ax.plot(xt, fcn(xt,*popt) )  # plot the model function
#  ,  label='a/((1-b)+(b/n)) with a=%2.6f b=%2.6f n=%2.6f' % tuple(popt)
max95 = fp16x2[-1]*0.95
xp = np.linspace(max95,max95,100)
ax.plot(xt,xp, color='y', label='95% of peak')

plt.xlabel("Watts")
plt.ylabel("images/sec")
plt.title("2 x RTX3090 TensorFlow ResNet50 fp16 -- Watts vs Performance", fontsize=18)
ax.legend()

# %%
fp16x3=np.array([
2061.9,
2291.0,
2375.9,
2683.8,
2857.1,
3003.1,
3087.4,
3145.3,
3196.9,
3235.1,
3259.6,
3288.8,
3324.7,
3335.1,
3361.1,
3369.5,
3379.2,
3396.2,])

# %%
popt, pcov = curve_fit(fcn, w, fp16x3)
popt
# Out:
# array([-4.31082184e+04, -3.05854664e+01,  9.75047166e+03])

# %%
plt.rcParams["figure.figsize"] = [12,7]
fig, ax = plt.subplots()
ax.plot( w, fp16x3, "o", color='g')  # plot the test data
xt = np.linspace(160,350,100)
ax.plot(xt, fcn(xt,*popt) )  # plot the model function
#  ,  label='a/((1-b)+(b/n)) with a=%2.6f b=%2.6f n=%2.6f' % tuple(popt)
max95 = fp16x3[-1]*0.95
xp = np.linspace(max95,max95,100)
ax.plot(xt,xp, color='y', label='95% of peak')

plt.xlabel("Watts")
plt.ylabel("images/sec")
plt.title("3 x RTX3090 TensorFlow ResNet50 fp16 -- Watts vs Performance", fontsize=18)
ax.legend()

# %%
fp16x4=np.array([
2665.7,
2770.9,
3058.7,
3521.2,
3868.5,
3964.9,
4075.6,
4152.6,
4211.4,
4253.2,
4314.6,
4370.5,
4384.2,
4413.8,
4445.7,
4466.8,
4474.8,
4488.9,])

# %%
popt, pcov = curve_fit(fcn, w, fp16x4)
popt
# Out:
# array([-6.40173161e+04, -4.56282759e+01,  1.43972671e+04])

# %%
plt.rcParams["figure.figsize"] = [12,7]
fig, ax = plt.subplots()
ax.plot( w, fp16x4, "o", color='g')  # plot the test data
xt = np.linspace(160,350,100)
ax.plot(xt, fcn(xt,*popt) )  # plot the model function
#  ,  label='a/((1-b)+(b/n)) with a=%2.6f b=%2.6f n=%2.6f' % tuple(popt)
max95 = fp16x4[-1]*0.95
xp = np.linspace(max95,max95,100)
ax.plot(xt,xp, color='y', label='95% of peak')

plt.xlabel("Watts")
plt.ylabel("images/sec")
plt.title("4 x RTX3090 TensorFlow ResNet50 fp16 -- Watts vs Performance", fontsize=18)
ax.legend()

# %%
fp32 = np.array([544.3,969.2,1434.3,1897.9])
#fp32 = fp32[0]/fp32
numgpus = np.array([1,2,3,4])
fp32
# Out:
# array([ 544.3,  969.2, 1434.3, 1897.9])

# %%
def amdhal(n,P):
    return fp32[0]/((1-P)+(P/n))

popt, pcov = curve_fit(amdhal, numgpus, fp32)
popt
# Out:
# array([0.9443848])

# %%
plt.rcParams["figure.figsize"] = [12,7]
#plt.figure(figsize=(16,9))
fig, ax = plt.subplots()
ax.plot( numgpus, fp32, "o", color='g', label='ResNet50 img/sec')  # plot the test data
#ax.plot( numgpus, stmv32, "x", color='r', label='NAMD STMV: "Wall Time 3970x')
ax.plot(4, 1803.7, "X", color='r', label='At 280W per GPU power limit')

xt = np.linspace(0.5,8,20)
ax.plot(xt, amdhal(xt,popt)  ,  label='Amdhals Eqn with P = %.4f ' %(popt[0]))  # plot the model function
#ax.plot(xt[:11], amdhal32(xt[:11],popt32)  ,  label='Amdhals Eqn with P = %.4f ' %(popt32[0]))

ax.plot(xt,fp32[0]*xt, color='k', label='Linear Scaling')

plt.xlabel("Number of GPUs")
plt.ylabel("Images/Second")
plt.title("Amdhal's Law, RXT3090 1-4 GPU Scaling \n TensorFlow 1.5 ResNet50 fp32", fontsize=18)
ax.legend()

# %%
tw = np.array([992,1218,1318,1400,1570])
#fp32 = fp32[0]/fp32
ips = np.array([3240,4180,4310,4403,4505])

# %%
popt, pcov = curve_fit(fcn, tw, ips)
popt
# Out:
# array([-9.28474838e+04, -1.00605252e+01,  1.53719843e+04])

# %%
plt.rcParams["figure.figsize"] = [12,7]
fig, ax = plt.subplots()
ax.plot( tw, ips, "o", color='g')  # plot the test data
xt = np.linspace(900,1600,100)
ax.plot(xt, fcn(xt,*popt) )  # plot the model function
#  ,  label='a/((1-b)+(b/n)) with a=%2.6f b=%2.6f n=%2.6f' % tuple(popt)
max95 = ips[-1]*0.95
xp = np.linspace(max95,max95,100)
ax.plot(xt,xp, color='y', label='95% of peak')
p=['200W/GPU 72% performance','250W/GPU 93% performance','275W/GPU 96% performance','300W/GPU 98% performance','350W/GPU 100% performance']
for i, txt in enumerate(p):
    ax.annotate(txt, (tw[i]+10, ips[i]-10))

plt.xlabel("Total System Watts at Wall")
plt.ylabel("images/sec")
plt.title("4 x RTX3090 TensorFlow ResNet50 fp16 -- Total System Watts vs Performance", fontsize=18)
ax.legend()
